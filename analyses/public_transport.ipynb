# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import duckdb
import requests
import json
import os
from dotenv import load_dotenv
import logging
from src.imports import get_stops
from src.data_processing import extract_stop_info, normalize_stops

load_dotenv()
# Out:
# True

# %%
stop_names = [
    "Hradčanská", "Sparta", "Korunovační", "Letenské náměstí",
    "Kamenická", "Strossmayerovo náměstí", "Nábřeží Kapitána Jaroše",
    "Vltavská", "Výstaviště", "Veletržní palác", "Chotkovy sady",
]
base_url = 'https://api.golemio.cz/v2/gtfs/stops'

# %%
letna_stops = get_stops(base_url, os.getenv('GOLEMIO_TOKEN'), stop_names)

# %%
stops_data_df = pd.DataFrame(extract_stop_info(letna_stops))

# %%
df = normalize_stops(stops_data_df)
df.to_csv('letna_stops.csv')

# %%
import folium
from folium.plugins import MarkerCluster, HeatMap

# %%
m = folium.Map(location=[df['avg_latitude'].mean(), df['avg_longitude'].mean()], zoom_start=14, tiles="CartoDB Positron")

marker_cluster = MarkerCluster().add_to(m)

# Add each stop to the map with modern, tooltip-only markers
for _, stop in df.iterrows():
    folium.CircleMarker(
        location=[stop["avg_latitude"], stop["avg_longitude"]],
        radius=8,  # Size of the circle marker
        color="#FF5733",  
        fill=True,
        fill_color="#FF5733",  
        fill_opacity=0.7,  # Fill transparency
        tooltip=stop["stop_name"],  # Tooltip displayed on hover
        popup=(f"<b>Stop Name:</b> {stop['stop_name']}<br>"
               f"<b>Base Stop ID:</b> {stop['base_stop_id']}<br>"
               f"<b>All Stop IDs:</b> {', '.join(stop['all_stop_ids'])}")
    ).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49af9f272a95bb88eedb578459652413 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49af9f272a95bb88eedb578459652413&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49af9f272a95bb88eedb578459652413 = L.map(
#                 &quot;map_49af9f272a95bb88eedb578459652413&quot;,
#                 {
#                     center: [50.09930278585859, 14.424610378787877],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3cc95308f301ae7b6c8e3e60b865bcaf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3cc95308f301ae7b6c8e3e60b865bcaf.addTo(map_49af9f272a95bb88eedb578459652413);
#
#
#             var marker_cluster_19ec6a0149587ced2eceaa1f82cf8d43 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_cc4976f7209caa6e6899b4e98f2c5951 = L.circleMarker(
#                 [50.095165, 14.4090435],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF5733&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF5733&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_19ec6a0149587ced2eceaa1f82cf8d43);
#
#
#         var popup_f8b25e6f4bfc298354cb440b3f320151 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_635b0dc44ac0d2f0a5b404b5067bc7a2 = $(`&lt;div id=&quot;html_635b0dc44ac0d2f0a5b404b5067bc7a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Stop Name:&lt;/b&gt; Chotkovy sady&lt;br&gt;&lt;b&gt;Base Stop ID:&lt;/b&gt; U187&lt;br&gt;&lt;b&gt;All Stop IDs:&lt;/b&gt; U187Z1P, U187Z2P&lt;/div&gt;`)[0];
#                 popup_f8b25e6f4bfc298354cb440b3f320151.setContent(html_635b0dc44ac0d2f0a5b404b5067bc7a2);
#
#
#
#         circle_marker_cc4976f7209caa6e6899b4e98f2c5951.bindPopup(popup_f8b25e6f4bfc298354cb440b3f320151)
#         ;
#
#
#
#
#             circle_marker_cc4976f7209caa6e6899b4e98f2c5951.bindTooltip(
#                 `&lt;div&gt;
#                      Chotkovy sady
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_49026fb6f31cdaa3c80b2cb90e3b20ac = L.circleMarker(
#                 [50.09749822222222, 14.404188666666666],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF5733&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF5733&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_19ec6a0149587ced2eceaa1f82cf8d43);
#
#
#         var popup_80e266bbe99ff24c845dd614d430584d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2754e6610414b4284d6845086f58d68 = $(`&lt;div id=&quot;html_b2754e6610414b4284d6845086f58d68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Stop Name:&lt;/b&gt; Hradčanská&lt;br&gt;&lt;b&gt;Base Stop ID:&lt;/b&gt; U163&lt;br&gt;&lt;b&gt;All Stop IDs:&lt;/b&gt; U163S1, U163Z1P, U163Z10P, U163Z101P, U163Z102P, U163Z2P, U163Z5P, U163Z6P, U163Z9P&lt;/div&gt;`)[0];
#                 popup_80e266bbe99ff24c845dd614d430584d.setContent(html_b2754e6610414b4284d6845086f58d68);
#
#
#
#         circle_marker_49026fb6f31cdaa3c80b2cb90e3b20ac.bindPopup(popup_80e266bbe99ff24c845dd614d430584d)
#         ;
#
#
#
#
#             circle_marker_49026fb6f31cdaa3c80b2cb90e3b20ac.bindTooltip(
#                 `&lt;div&gt;
#                      Hradčanská
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %%
def setup_azure_duckdb(duckdb_conn: duckdb.DuckDBPyConnection) -> None:
    duckdb_conn.sql(f"ATTACH 'public-transport.db';")
    duckdb_conn.sql('INSTALL azure; LOAD azure;')
    duckdb_conn.sql(f'''
        CREATE SECRET azure_spn (
            TYPE AZURE,
            PROVIDER SERVICE_PRINCIPAL,
            TENANT_ID '{os.getenv("parquetAzureTenantID")}',
            CLIENT_ID '{os.getenv("parquetAzureAppID")}',
            CLIENT_SECRET '{os.getenv("parquetAzureClientSecret")}',
            ACCOUNT_NAME '{os.getenv("parquetStorageName")}');
            ''')
    logging.info("Azure and DuckDB setup complete")
    
def get_stop_times_from_azure(duckdb_conn, stop_ids) -> pd.DataFrame:
    stop_times_sql_string = f'''
    SELECT * 
        FROM 'azure://golem-data-lake-pid/vehiclepositions_stop_times_history/*/*/*/*.parquet'
        WHERE YEAR = 2024 AND gtfs_stop_id IN ({stop_ids})
    '''
    logging.info("Getting stop times from Azure")
    return duckdb_conn.sql(stop_times_sql_string).df()

# %%
with duckdb.connect('duck.db') as duckdb_conn:
    stop_ids_sql = ", ".join([f"'{stop_id}'" for stop_id in stops_data_df['stop_id'].to_list()])
    setup_azure_duckdb(duckdb_conn)
    stop_times_df = get_stop_times_from_azure(duckdb_conn, stop_ids_sql)
    logging.info('Stop times data loaded')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
stop_times_df.to_csv('stop_times.csv', index=False)

# %%
stop_times_df = stop_times_df.assign(
    current_stop_departure = pd.to_datetime(stop_times_df['current_stop_departure']),  
    current_stop_arrival = pd.to_datetime(stop_times_df['current_stop_arrival']),
    created_at = pd.to_datetime(stop_times_df['created_at']),
    updated_at = pd.to_datetime(stop_times_df['updated_at']),
    base_stop_id = stop_times_df['gtfs_stop_id'].str.extract(r'^(.*?)(?=[SZ])')[0]
)

# %%
stop_times_df.columns
# Out:
# Index(['rt_trip_id', 'gtfs_date', 'gtfs_trip_id', 'gtfs_direction_id',
#        'gtfs_route_short_name', 'gtfs_route_type', 'run_number',
#        'vehicle_registration_number', 'gtfs_stop_sequence', 'gtfs_stop_id',
#        'current_stop_arrival', 'current_stop_departure',
#        'current_stop_arr_delay', 'current_stop_dep_delay', 'create_batch_id',
#        'created_at', 'created_by', 'update_batch_id', 'updated_at',
#        'updated_by', 'origin_route_name', 'day', 'month', 'year'],
#       dtype='object')

# %%
stop_times_df
# Out:
#                                              rt_trip_id   gtfs_date  \
# 449944    2024-05-31T23:30:00+02:00_94_1867_240428_8278  2024-05-31
# 449945    2024-05-31T23:30:00+02:00_94_1867_240428_8278  2024-05-31
# 449946    2024-05-31T23:30:00+02:00_94_1867_240428_8278  2024-05-31
# 449955    2024-06-01T00:08:00+02:00_97_1401_231206_8363  2024-05-31
# 449951    2024-06-01T00:00:00+02:00_94_1860_240527_8464  2024-05-31
# ...                                                 ...         ...
# 747532  2024-12-31T23:34:05+01:00_993_3643_210715_26_26  2024-12-31
# 747512    2024-12-31T23:02:00+01:00_97_1898_241231_9425  2024-12-31
# 747534  2024-12-31T23:41:40+01:00_991_1338_241224_16_16  2024-12-31
# 747531    2024-12-31T23:33:35+01:00_991_1339_241223_4_4  2024-12-31
# 747533  2024-12-31T23:34:15+01:00_993_3638_210715_30_30  2024-12-31
#
#            gtfs_trip_id  gtfs_direction_id gtfs_route_short_name  \
# 449944   94_1867_240428                  0                    94
# 449945   94_1867_240428                  0                    94
# 449946   94_1867_240428                  0                    94
# 449955   97_1401_231206                  0                    97
# 449951   94_1860_240527                  0                    94
# ...                 ...                ...                   ...
# 747532  993_3643_210715                  0                     C
# 747512   97_1898_241231                  1                    97
# 747534  991_1338_241224                  1                     A
# 747531  991_1339_241223                  0                     A
# 747533  993_3638_210715                  1                     C
#
#         gtfs_route_type  run_number  vehicle_registration_number  \
# 449944                0          74                       8278.0
# 449945                0          74                       8278.0
# 449946                0          74                       8278.0
# 449955                0          55                       8363.0
# 449951                0          61                       8464.0
# ...                 ...         ...                          ...
# 747532                1          26                          NaN
# 747512                0          61                       9425.0
# 747534                1          16                          NaN
# 747531                1           4                          NaN
# 747533                1          30                          NaN
#
#         gtfs_stop_sequence gtfs_stop_id  ... create_batch_id  \
# 449944                  23      U100Z4P  ...            None
# 449945                  24      U717Z2P  ...            None
# 449946                  25      U439Z1P  ...            None
# 449955                  14      U163Z1P  ...            None
# 449951                  23      U100Z4P  ...            None
# ...                    ...          ...  ...             ...
# 747532                   7    U100Z102P  ...            None
# 747512                  34      U163Z2P  ...            None
# 747534                   6    U163Z101P  ...            None
# 747531                  12    U163Z102P  ...            None
# 747533                  14    U100Z101P  ...            None
#
#                              created_at  created_by  update_batch_id  \
# 449944 2024-06-01 02:18:00.083005+02:00        None             None
# 449945 2024-06-01 02:18:00.083005+02:00        None             None
# 449946 2024-06-01 02:18:00.083005+02:00        None             None
# 449955 2024-06-01 02:18:00.083005+02:00        None             None
# 449951 2024-06-01 02:18:00.083005+02:00        None             None
# ...                                 ...         ...              ...
# 747532 2025-01-01 00:48:00.058105+01:00        None             None
# 747512 2025-01-01 00:48:00.058105+01:00        None             None
# 747534 2025-01-01 00:48:00.058105+01:00        None             None
# 747531 2025-01-01 00:48:00.058105+01:00        None             None
# 747533 2025-01-01 00:48:00.058105+01:00        None             None
#
#                              updated_at updated_by origin_route_name day  \
# 449944 2024-06-01 02:18:00.083005+02:00       None                94   1
# 449945 2024-06-01 02:18:00.083005+02:00       None                94   1
# 449946 2024-06-01 02:18:00.083005+02:00       None                94   1
# 449955 2024-06-01 02:18:00.083005+02:00       None                97   1
# 449951 2024-06-01 02:18:00.083005+02:00       None                94   1
# ...                                 ...        ...               ...  ..
# 747532 2025-01-01 00:48:00.058105+01:00       None               993  31
# 747512 2025-01-01 00:48:00.058105+01:00       None                22  31
# 747534 2025-01-01 00:48:00.058105+01:00       None               991  31
# 747531 2025-01-01 00:48:00.058105+01:00       None               991  31
# 747533 2025-01-01 00:48:00.058105+01:00       None               993  31
#
#        month  year
# 449944     6  2024
# 449945     6  2024
# 449946     6  2024
# 449955     6  2024
# 449951     6  2024
# ...      ...   ...
# 747532    12  2024
# 747512    12  2024
# 747534    12  2024
# 747531    12  2024
# 747533    12  2024
#
# [2425993 rows x 24 columns]

# %%
df
# Out:
#                   stop_name  avg_longitude  avg_latitude base_stop_id  \
# 0             Chotkovy sady      14.409043     50.095165         U187
# 1                Hradčanská      14.404189     50.097498         U163
# 2                 Kamenická      14.428636     50.099638         U231
# 3               Korunovační      14.419715     50.100393         U262
# 4          Letenské náměstí      14.423605     50.099975         U324
# 5   Nábřeží Kapitána Jaroše      14.431299     50.096321         U439
# 6                    Sparta      14.417687     50.099160         U692
# 7    Strossmayerovo náměstí      14.433265     50.098910         U717
# 8           Veletržní palác      14.433064     50.101734         U841
# 9                  Vltavská      14.438300     50.099185         U100
# 10               Výstaviště      14.431911     50.104351         U532
#
#                                          all_stop_ids
# 0                                  [U187Z1P, U187Z2P]
# 1   [U163S1, U163Z1P, U163Z10P, U163Z101P, U163Z10...
# 2                                  [U231Z1P, U231Z2P]
# 3                         [U262Z2P, U262Z3P, U262Z4P]
# 4                                  [U324Z1P, U324Z2P]
# 5                                           [U439Z1P]
# 6                [U692Z1P, U692Z2P, U692Z3P, U692Z4P]
# 7                [U717Z1P, U717Z2P, U717Z4P, U717Z5P]
# 8                         [U841Z1P, U841Z2P, U841Z4P]
# 9   [U100S1, U100Z1P, U100Z101P, U100Z102P, U100Z2...
# 10     [U532Z1P, U532Z2P, U532Z3P, U532Z4P, U532Z53P]

# %%
stop_times_df.merge(df, left_on='stop_id_base', right_on='base_stop_id', how='inner')
# Out:
#                                             rt_trip_id   gtfs_date  \
# 0        2024-05-31T23:30:00+02:00_94_1867_240428_8278  2024-05-31
# 1        2024-06-01T00:00:00+02:00_94_1860_240527_8464  2024-05-31
# 2        2024-06-01T00:00:00+02:00_911_490_240428_6741  2024-05-31
# 3        2024-06-01T00:17:00+02:00_905_257_240428_6820  2024-05-31
# 4        2024-06-01T00:06:00+02:00_911_493_240428_6669  2024-05-31
# ...                                                ...         ...
# 2425988  2024-12-31T22:42:00+01:00_91_1980_241231_9430  2024-12-31
# 2425989  2024-12-31T22:58:00+01:00_91_2004_241231_9281  2024-12-31
# 2425990   2024-12-31T22:54:00+01:00_96_992_241231_9229  2024-12-31
# 2425991   2024-12-31T23:12:00+01:00_96_980_241231_9301  2024-12-31
# 2425992  2024-12-31T22:48:00+01:00_91_2015_241231_8286  2024-12-31
#
#            gtfs_trip_id  gtfs_direction_id gtfs_route_short_name  \
# 0        94_1867_240428                  0                    94
# 1        94_1860_240527                  0                    94
# 2        911_490_240428                  0                   911
# 3        905_257_240428                  0                   905
# 4        911_493_240428                  1                   911
# ...                 ...                ...                   ...
# 2425988  91_1980_241231                  1                    91
# 2425989  91_2004_241231                  0                    91
# 2425990   96_992_241231                  1                    96
# 2425991   96_980_241231                  0                    96
# 2425992  91_2015_241231                  1                    91
#
#          gtfs_route_type  run_number  vehicle_registration_number  \
# 0                      0          74                       8278.0
# 1                      0          61                       8464.0
# 2                      3          55                       6741.0
# 3                      3          56                       6820.0
# 4                      3          51                       6669.0
# ...                  ...         ...                          ...
# 2425988                0          60                       9430.0
# 2425989                0          56                       9281.0
# 2425990                0          60                       9229.0
# 2425991                0          56                       9301.0
# 2425992                0          61                       8286.0
#
#          gtfs_stop_sequence gtfs_stop_id  ... origin_route_name day  month  \
# 0                        23      U100Z4P  ...                94   1      6
# 1                        23      U100Z4P  ...                94   1      6
# 2                        24      U100Z6P  ...               911   1      6
# 3                        22      U100Z6P  ...               905   1      6
# 4                        19      U100Z5P  ...               911   1      6
# ...                     ...          ...  ...               ...  ..    ...
# 2425988                  30      U231Z2P  ...                 5  31     12
# 2425989                  20      U231Z1P  ...                26  31     12
# 2425990                  24      U231Z2P  ...                 6  31     12
# 2425991                  13      U231Z1P  ...                 1  31     12
# 2425992                  38      U231Z2P  ...                26  31     12
#
#          year stop_id_base  stop_name avg_longitude avg_latitude base_stop_id  \
# 0        2024         U100   Vltavská     14.438300    50.099185         U100
# 1        2024         U100   Vltavská     14.438300    50.099185         U100
# 2        2024         U100   Vltavská     14.438300    50.099185         U100
# 3        2024         U100   Vltavská     14.438300    50.099185         U100
# 4        2024         U100   Vltavská     14.438300    50.099185         U100
# ...       ...          ...        ...           ...          ...          ...
# 2425988  2024         U231  Kamenická     14.428636    50.099638         U231
# 2425989  2024         U231  Kamenická     14.428636    50.099638         U231
# 2425990  2024         U231  Kamenická     14.428636    50.099638         U231
# 2425991  2024         U231  Kamenická     14.428636    50.099638         U231
# 2425992  2024         U231  Kamenická     14.428636    50.099638         U231
#
#                                               all_stop_ids
# 0        [U100S1, U100Z1P, U100Z101P, U100Z102P, U100Z2...
# 1        [U100S1, U100Z1P, U100Z101P, U100Z102P, U100Z2...
# 2        [U100S1, U100Z1P, U100Z101P, U100Z102P, U100Z2...
# 3        [U100S1, U100Z1P, U100Z101P, U100Z102P, U100Z2...
# 4        [U100S1, U100Z1P, U100Z101P, U100Z102P, U100Z2...
# ...                                                    ...
# 2425988                                 [U231Z1P, U231Z2P]
# 2425989                                 [U231Z1P, U231Z2P]
# 2425990                                 [U231Z1P, U231Z2P]
# 2425991                                 [U231Z1P, U231Z2P]
# 2425992                                 [U231Z1P, U231Z2P]
#
# [2425993 rows x 30 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_sparta_matches():
    # URL of Sparta Praha's match schedule
    url = 'https://www.eurofotbal.cz/kluby/cesko/sparta-praha/zapasy/'
    
    # Send a GET request to the URL
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    response = requests.get(url, headers=headers)
    
    # Check if the request was successful
    if response.status_code != 200:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        return None
    
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all match rows
    match_rows = soup.find_all('div', class_='e-tables-table-overview__row e-tables-table-overview__row--hoverable')
    
    matches = []
    
    for row in match_rows:
        # Extract competition
        competition_cell = row.find('div', class_='e-tables-table-overview__cell--league')
        competition = competition_cell.text.strip() if competition_cell else "Unknown"
        
        # Extract round
        round_cell = row.find('div', class_='e-tables-table-overview__cell--round')
        round_text = round_cell.text.strip() if round_cell else "Unknown"
        
        # Extract date and time - specifically targeting the third and fourth cells
        date_cells = row.find_all('div', class_='e-tables-table-overview__cell--gray')
        
        date = "Unknown"
        time = "Unknown"
        
        if len(date_cells) >= 3:
            date = date_cells[2].text.strip()
        
        if len(date_cells) >= 4:
            time = date_cells[3].text.strip()
        
        # Extract teams
        team_cells = row.find_all('div', class_='e-tables-table-overview__result-team-label')
        home_team = team_cells[0].text.strip()
        away_team = team_cells[1].text.strip()
        
        # Determine Sparta's position (home or away)
        sparta_home = home_team == "Sparta Praha"
        sparta_away = away_team == "Sparta Praha"
        
        # Extract score
        score_cell = row.find('span', class_='e-tables-table-overview__result-score-inner')
        score = score_cell.text.strip() if score_cell else "- : -"
        
        # Determine result color
        result_color = score_cell['class'][-1] if score_cell and len(score_cell.get('class', [])) > 0 else "Unknown"
        
        match_data = {
            'Competition': competition,
            'Round': round_text,
            'Date': date,
            'Time': time,
            'Home Team': home_team,
            'Away Team': away_team,
            'Sparta Position': 'Home' if sparta_home else 'Away' if sparta_away else 'N/A',
            'Score': score,
            'Result Color': result_color
        }
        
        matches.append(match_data)
    
    return pd.DataFrame(matches)

# Scrape and save matches
df = scrape_sparta_matches()

if df is not None:
    # Save to CSV
    df.to_csv('sparta_matches.csv', index=False, encoding='utf-8')

    # Print summary
    print(df)
    print(f"\nTotal matches: {len(df)}")
    
    # Additional analysis
    print("\nCompetitions:")
    print(df['Competition'].value_counts())
    
    print("\nSparta's Home/Away Matches:")
    print(df['Sparta Position'].value_counts())
# Out:
#     Competition     Round        Date   Time        Home Team  \
# 0   Chance Liga   1. kolo  19.07.2024  19:00     Sparta Praha
# 1   Liga mistrů  2.př 1.z  23.07.2024  21:00  Shamrock Rovers
# 2   Chance Liga   2. kolo  27.07.2024  17:00       FK Teplice
# 3   Liga mistrů  2.př 2.z  30.07.2024  19:00     Sparta Praha
# 4   Chance Liga   3. kolo  02.08.2024  20:00     Sparta Praha
# 5   Liga mistrů  3.př 1.z  06.08.2024  20:00     Sparta Praha
# 6   Chance Liga   4. kolo  10.08.2024  17:00   Bohemians 1905
# 7   Liga mistrů  3.př 2.z  13.08.2024  20:30             FCSB
# 8   Chance Liga   5. kolo  17.08.2024  20:00      FK Jablonec
# 9   Liga mistrů  4.př 1.z  21.08.2024  21:00         Malmö FF
# 10  Chance Liga   6. kolo  24.08.2024  17:00     Sparta Praha
# 11  Liga mistrů  4.př 2.z  27.08.2024  21:00     Sparta Praha
# 12  Chance Liga   7. kolo  31.08.2024  20:00     Hradec Král.
# 13  Liga mistrů      Hl.f  18.09.2024  18:45     Sparta Praha
# 14  Chance Liga   9. kolo  22.09.2024  15:30    Č. Budějovice
# 15  Chance Liga  10. kolo  27.09.2024  19:30     Sparta Praha
# 16  Liga mistrů      Hl.f  01.10.2024  18:45    VfB Stuttgart
# 17  Chance Liga  11. kolo  06.10.2024  18:30     Slavia Praha
# 18  Chance Liga  12. kolo  19.10.2024  19:00     Sparta Praha
# 19  Liga mistrů      Hl.f  23.10.2024  21:00  Manchester City
# 20  Chance Liga  13. kolo  27.10.2024  18:30   Viktoria Plzeň
# 21      MOL Cup       3.k  30.10.2024  19:15     Sparta Praha
# 22  Chance Liga  14. kolo  02.11.2024  19:00     Sparta Praha
# 23  Liga mistrů      Hl.f  06.11.2024  21:00     Sparta Praha
# 24  Chance Liga  15. kolo  10.11.2024  15:30     Ml. Boleslav
# 25  Chance Liga  16. kolo  23.11.2024  16:00     Sparta Praha
# 26  Liga mistrů      Hl.f  26.11.2024  18:45     Sparta Praha
# 27  Chance Liga  17. kolo  30.11.2024  19:00      Dukla Praha
# 28  Chance Liga   8. kolo  03.12.2024  19:00     Sparta Praha
# 29  Chance Liga  18. kolo  07.12.2024  19:00     Sparta Praha
# 30  Liga mistrů      Hl.f  11.12.2024  21:00        Feyenoord
# 31  Chance Liga  19. kolo  15.12.2024  13:00     Sparta Praha
# 32  Liga mistrů      Hl.f  22.01.2025  21:00     Sparta Praha
# 33  Liga mistrů      Hl.f  29.01.2025  21:00       Leverkusen
# 34  Chance Liga  20. kolo  02.02.2025  13:00   1. FC Slovácko
# 35  Chance Liga  21. kolo  09.02.2025  18:30     Sparta Praha
# 36  Chance Liga  22. kolo  15.02.2025  19:00      MFK Karviná
# 37  Chance Liga  23. kolo  22.02.2025      ?     Sparta Praha
# 38      MOL Cup        OF  26.02.2025      ?     Sparta Praha
# 39  Chance Liga  24. kolo  01.03.2025      ?    Sigma Olomouc
# 40  Chance Liga  25. kolo  08.03.2025      ?     Sparta Praha
# 41  Chance Liga  26. kolo  15.03.2025      ?   Slovan Liberec
# 42  Chance Liga  27. kolo  29.03.2025      ?     Sparta Praha
# 43  Chance Liga  28. kolo  05.04.2025      ?    Baník Ostrava
# 44  Chance Liga  29. kolo  12.04.2025      ?     Sparta Praha
# 45  Chance Liga  30. kolo  19.04.2025      ?     FK Pardubice
#
#           Away Team Sparta Position  Score  \
# 0      FK Pardubice            Home    2:1
# 1      Sparta Praha            Away    0:2
# 2      Sparta Praha            Away    1:4
# 3   Shamrock Rovers            Home    4:2
# 4       Dukla Praha            Home    2:0
# 5              FCSB            Home    1:1
# 6      Sparta Praha            Away    1:2
# 7      Sparta Praha            Away    2:3
# 8      Sparta Praha            Away    1:2
# 9      Sparta Praha            Away    0:2
# 10   1. FC Slovácko            Home    2:2
# 11         Malmö FF            Home    2:0
# 12     Sparta Praha            Away    0:2
# 13         Salzburg            Home    3:0
# 14     Sparta Praha            Away    0:2
# 15    Sigma Olomouc            Home    2:3
# 16     Sparta Praha            Away    1:1
# 17     Sparta Praha            Away    2:1
# 18   Slovan Liberec            Home    2:1
# 19     Sparta Praha            Away    5:0
# 20     Sparta Praha            Away    1:0
# 21   Zbrojovka Brno            Home    4:0
# 22    Baník Ostrava            Home    1:3
# 23   Stade Brestois            Home    1:2
# 24     Sparta Praha            Away    2:2
# 25       FK Teplice            Home    1:1
# 26      Atl. Madrid            Home    0:6
# 27     Sparta Praha            Away    1:1
# 28      MFK Karviná            Home    4:1
# 29   Bohemians 1905            Home    1:0
# 30     Sparta Praha            Away    4:2
# 31      FK Jablonec            Home    2:1
# 32      Inter Milán            Home  - : -
# 33     Sparta Praha            Away  - : -
# 34     Sparta Praha            Away  - : -
# 35     Hradec Král.            Home  - : -
# 36     Sparta Praha            Away  - : -
# 37    Č. Budějovice            Home  - : -
# 38      Dukla Praha            Home  - : -
# 39     Sparta Praha            Away  - : -
# 40     Slavia Praha            Home  - : -
# 41     Sparta Praha            Away  - : -
# 42   Viktoria Plzeň            Home  - : -
# 43     Sparta Praha            Away  - : -
# 44     Ml. Boleslav            Home  - : -
# 45     Sparta Praha            Away  - : -
#
#                                    Result Color
# 0            e-tables-table-overview__bg--green
# 1            e-tables-table-overview__bg--green
# 2            e-tables-table-overview__bg--green
# 3            e-tables-table-overview__bg--green
# 4            e-tables-table-overview__bg--green
# 5           e-tables-table-overview__bg--yellow
# 6            e-tables-table-overview__bg--green
# 7            e-tables-table-overview__bg--green
# 8            e-tables-table-overview__bg--green
# 9            e-tables-table-overview__bg--green
# 10          e-tables-table-overview__bg--yellow
# 11           e-tables-table-overview__bg--green
# 12           e-tables-table-overview__bg--green
# 13           e-tables-table-overview__bg--green
# 14           e-tables-table-overview__bg--green
# 15             e-tables-table-overview__bg--red
# 16          e-tables-table-overview__bg--yellow
# 17             e-tables-table-overview__bg--red
# 18           e-tables-table-overview__bg--green
# 19             e-tables-table-overview__bg--red
# 20             e-tables-table-overview__bg--red
# 21           e-tables-table-overview__bg--green
# 22             e-tables-table-overview__bg--red
# 23             e-tables-table-overview__bg--red
# 24          e-tables-table-overview__bg--yellow
# 25          e-tables-table-overview__bg--yellow
# 26             e-tables-table-overview__bg--red
# 27          e-tables-table-overview__bg--yellow
# 28           e-tables-table-overview__bg--green
# 29           e-tables-table-overview__bg--green
# 30             e-tables-table-overview__bg--red
# 31           e-tables-table-overview__bg--green
# 32  e-tables-table-overview__result-score-inner
# 33  e-tables-table-overview__result-score-inner
# 34  e-tables-table-overview__result-score-inner
# 35  e-tables-table-overview__result-score-inner
# 36  e-tables-table-overview__result-score-inner
# 37  e-tables-table-overview__result-score-inner
# 38  e-tables-table-overview__result-score-inner
# 39  e-tables-table-overview__result-score-inner
# 40  e-tables-table-overview__result-score-inner
# 41  e-tables-table-overview__result-score-inner
# 42  e-tables-table-overview__result-score-inner
# 43  e-tables-table-overview__result-score-inner
# 44  e-tables-table-overview__result-score-inner
# 45  e-tables-table-overview__result-score-inner
#
# Total matches: 46
#
# Competitions:
# Competition
# Chance Liga    30
# Liga mistrů    14
# MOL Cup         2
# Name: count, dtype: int64
#
# Sparta's Home/Away Matches:
# Sparta Position
# Home    24
# Away    22
# Name: count, dtype: int64

# %%
df
# Out:
#     Competition     Round        Date   Time        Home Team  \
# 0   Chance Liga   1. kolo  19.07.2024  19:00     Sparta Praha
# 1   Liga mistrů  2.př 1.z  23.07.2024  21:00  Shamrock Rovers
# 2   Chance Liga   2. kolo  27.07.2024  17:00       FK Teplice
# 3   Liga mistrů  2.př 2.z  30.07.2024  19:00     Sparta Praha
# 4   Chance Liga   3. kolo  02.08.2024  20:00     Sparta Praha
# 5   Liga mistrů  3.př 1.z  06.08.2024  20:00     Sparta Praha
# 6   Chance Liga   4. kolo  10.08.2024  17:00   Bohemians 1905
# 7   Liga mistrů  3.př 2.z  13.08.2024  20:30             FCSB
# 8   Chance Liga   5. kolo  17.08.2024  20:00      FK Jablonec
# 9   Liga mistrů  4.př 1.z  21.08.2024  21:00         Malmö FF
# 10  Chance Liga   6. kolo  24.08.2024  17:00     Sparta Praha
# 11  Liga mistrů  4.př 2.z  27.08.2024  21:00     Sparta Praha
# 12  Chance Liga   7. kolo  31.08.2024  20:00     Hradec Král.
# 13  Liga mistrů      Hl.f  18.09.2024  18:45     Sparta Praha
# 14  Chance Liga   9. kolo  22.09.2024  15:30    Č. Budějovice
# 15  Chance Liga  10. kolo  27.09.2024  19:30     Sparta Praha
# 16  Liga mistrů      Hl.f  01.10.2024  18:45    VfB Stuttgart
# 17  Chance Liga  11. kolo  06.10.2024  18:30     Slavia Praha
# 18  Chance Liga  12. kolo  19.10.2024  19:00     Sparta Praha
# 19  Liga mistrů      Hl.f  23.10.2024  21:00  Manchester City
# 20  Chance Liga  13. kolo  27.10.2024  18:30   Viktoria Plzeň
# 21      MOL Cup       3.k  30.10.2024  19:15     Sparta Praha
# 22  Chance Liga  14. kolo  02.11.2024  19:00     Sparta Praha
# 23  Liga mistrů      Hl.f  06.11.2024  21:00     Sparta Praha
# 24  Chance Liga  15. kolo  10.11.2024  15:30     Ml. Boleslav
# 25  Chance Liga  16. kolo  23.11.2024  16:00     Sparta Praha
# 26  Liga mistrů      Hl.f  26.11.2024  18:45     Sparta Praha
# 27  Chance Liga  17. kolo  30.11.2024  19:00      Dukla Praha
# 28  Chance Liga   8. kolo  03.12.2024  19:00     Sparta Praha
# 29  Chance Liga  18. kolo  07.12.2024  19:00     Sparta Praha
# 30  Liga mistrů      Hl.f  11.12.2024  21:00        Feyenoord
# 31  Chance Liga  19. kolo  15.12.2024  13:00     Sparta Praha
# 32  Liga mistrů      Hl.f  22.01.2025  21:00     Sparta Praha
# 33  Liga mistrů      Hl.f  29.01.2025  21:00       Leverkusen
# 34  Chance Liga  20. kolo  02.02.2025  13:00   1. FC Slovácko
# 35  Chance Liga  21. kolo  09.02.2025  18:30     Sparta Praha
# 36  Chance Liga  22. kolo  15.02.2025  19:00      MFK Karviná
# 37  Chance Liga  23. kolo  22.02.2025      ?     Sparta Praha
# 38      MOL Cup        OF  26.02.2025      ?     Sparta Praha
# 39  Chance Liga  24. kolo  01.03.2025      ?    Sigma Olomouc
# 40  Chance Liga  25. kolo  08.03.2025      ?     Sparta Praha
# 41  Chance Liga  26. kolo  15.03.2025      ?   Slovan Liberec
# 42  Chance Liga  27. kolo  29.03.2025      ?     Sparta Praha
# 43  Chance Liga  28. kolo  05.04.2025      ?    Baník Ostrava
# 44  Chance Liga  29. kolo  12.04.2025      ?     Sparta Praha
# 45  Chance Liga  30. kolo  19.04.2025      ?     FK Pardubice
#
#           Away Team Sparta Position  Score  \
# 0      FK Pardubice            Home    2:1
# 1      Sparta Praha            Away    0:2
# 2      Sparta Praha            Away    1:4
# 3   Shamrock Rovers            Home    4:2
# 4       Dukla Praha            Home    2:0
# 5              FCSB            Home    1:1
# 6      Sparta Praha            Away    1:2
# 7      Sparta Praha            Away    2:3
# 8      Sparta Praha            Away    1:2
# 9      Sparta Praha            Away    0:2
# 10   1. FC Slovácko            Home    2:2
# 11         Malmö FF            Home    2:0
# 12     Sparta Praha            Away    0:2
# 13         Salzburg            Home    3:0
# 14     Sparta Praha            Away    0:2
# 15    Sigma Olomouc            Home    2:3
# 16     Sparta Praha            Away    1:1
# 17     Sparta Praha            Away    2:1
# 18   Slovan Liberec            Home    2:1
# 19     Sparta Praha            Away    5:0
# 20     Sparta Praha            Away    1:0
# 21   Zbrojovka Brno            Home    4:0
# 22    Baník Ostrava            Home    1:3
# 23   Stade Brestois            Home    1:2
# 24     Sparta Praha            Away    2:2
# 25       FK Teplice            Home    1:1
# 26      Atl. Madrid            Home    0:6
# 27     Sparta Praha            Away    1:1
# 28      MFK Karviná            Home    4:1
# 29   Bohemians 1905            Home    1:0
# 30     Sparta Praha            Away    4:2
# 31      FK Jablonec            Home    2:1
# 32      Inter Milán            Home  - : -
# 33     Sparta Praha            Away  - : -
# 34     Sparta Praha            Away  - : -
# 35     Hradec Král.            Home  - : -
# 36     Sparta Praha            Away  - : -
# 37    Č. Budějovice            Home  - : -
# 38      Dukla Praha            Home  - : -
# 39     Sparta Praha            Away  - : -
# 40     Slavia Praha            Home  - : -
# 41     Sparta Praha            Away  - : -
# 42   Viktoria Plzeň            Home  - : -
# 43     Sparta Praha            Away  - : -
# 44     Ml. Boleslav            Home  - : -
# 45     Sparta Praha            Away  - : -
#
#                                    Result Color
# 0            e-tables-table-overview__bg--green
# 1            e-tables-table-overview__bg--green
# 2            e-tables-table-overview__bg--green
# 3            e-tables-table-overview__bg--green
# 4            e-tables-table-overview__bg--green
# 5           e-tables-table-overview__bg--yellow
# 6            e-tables-table-overview__bg--green
# 7            e-tables-table-overview__bg--green
# 8            e-tables-table-overview__bg--green
# 9            e-tables-table-overview__bg--green
# 10          e-tables-table-overview__bg--yellow
# 11           e-tables-table-overview__bg--green
# 12           e-tables-table-overview__bg--green
# 13           e-tables-table-overview__bg--green
# 14           e-tables-table-overview__bg--green
# 15             e-tables-table-overview__bg--red
# 16          e-tables-table-overview__bg--yellow
# 17             e-tables-table-overview__bg--red
# 18           e-tables-table-overview__bg--green
# 19             e-tables-table-overview__bg--red
# 20             e-tables-table-overview__bg--red
# 21           e-tables-table-overview__bg--green
# 22             e-tables-table-overview__bg--red
# 23             e-tables-table-overview__bg--red
# 24          e-tables-table-overview__bg--yellow
# 25          e-tables-table-overview__bg--yellow
# 26             e-tables-table-overview__bg--red
# 27          e-tables-table-overview__bg--yellow
# 28           e-tables-table-overview__bg--green
# 29           e-tables-table-overview__bg--green
# 30             e-tables-table-overview__bg--red
# 31           e-tables-table-overview__bg--green
# 32  e-tables-table-overview__result-score-inner
# 33  e-tables-table-overview__result-score-inner
# 34  e-tables-table-overview__result-score-inner
# 35  e-tables-table-overview__result-score-inner
# 36  e-tables-table-overview__result-score-inner
# 37  e-tables-table-overview__result-score-inner
# 38  e-tables-table-overview__result-score-inner
# 39  e-tables-table-overview__result-score-inner
# 40  e-tables-table-overview__result-score-inner
# 41  e-tables-table-overview__result-score-inner
# 42  e-tables-table-overview__result-score-inner
# 43  e-tables-table-overview__result-score-inner
# 44  e-tables-table-overview__result-score-inner
# 45  e-tables-table-overview__result-score-inner
