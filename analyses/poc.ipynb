# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import duckdb

# %% [markdown]
# ### Stop names and info

# %%
base_url = 'https://api.golemio.cz/v2/gtfs/stops'

# stop_names for Letná district
stop_names = [
    "Hradčanská", "Sparta", "Korunovační", "Letenské náměstí",
    "Kamenická", "Strossmayerovo náměstí", "Nábřeží Kapitána Jaroše",
    "Vltavská", "Výstaviště", "Veletržní palác"
]

params = {
    'names[]': stop_names,
    'offset': 0
}

headers = {
    'accept': 'application/json',
    'X-Access-Token': os.getenv('X-Access-Token-Golemio')
    }

response = requests.get(base_url, params=params, headers=headers)

# %%
feat = response.json()['features']
stops = []
for x in feat:
    stops.append(x['properties']['stop_name'])

# %%
len(set(stops)) == len(stop_names)
# Out:
# True

# %%
feat
# Out:
# [{'geometry': {'coordinates': [14.438508, 50.100229], 'type': 'Point'},
#   'properties': {'location_type': 1,
#    'parent_station': None,
#    'platform_code': None,
#    'stop_id': 'U100S1',
#    'stop_name': 'Vltavská',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.438122, 50.099228], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'A',
#    'stop_id': 'U100Z1P',
#    'stop_name': 'Vltavská',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.438596, 50.100229], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': 'U100S1',
#    'platform_code': '1',
#    'stop_id': 'U100Z101P',
#    'stop_name': 'Vltavská',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': 'U100L2'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.438395, 50.100227], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': 'U100S1',
#    'platform_code': '2',
#    'stop_id': 'U100Z102P',
#    'stop_name': 'Vltavská',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': 'U100L2'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.438766, 50.098812], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'B',
#    'stop_id': 'U100Z2P',
#    'stop_name': 'Vltavská',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.437243, 50.098469], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U100Z3P',
#    'stop_name': 'Vltavská',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.437513, 50.099022], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'D',
#    'stop_id': 'U100Z4P',
#    'stop_name': 'Vltavská',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.43881, 50.09811], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'E',
#    'stop_id': 'U100Z5P',
#    'stop_name': 'Vltavská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.438747, 50.098335], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'F',
#    'stop_id': 'U100Z6P',
#    'stop_name': 'Vltavská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.403194, 50.097453], 'type': 'Point'},
#   'properties': {'location_type': 1,
#    'parent_station': None,
#    'platform_code': None,
#    'stop_id': 'U163S1',
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 2,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.404873, 50.097298], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'A',
#    'stop_id': 'U163Z1P',
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.402766, 50.096996], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'L',
#    'stop_id': 'U163Z10P',
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.403122, 50.097342], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': 'U163S1',
#    'platform_code': '1',
#    'stop_id': 'U163Z101P',
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 2,
#    'zone_id': 'P',
#    'level_id': 'U163L2'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.403233, 50.097544], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': 'U163S1',
#    'platform_code': '2',
#    'stop_id': 'U163Z102P',
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 2,
#    'zone_id': 'P',
#    'level_id': 'U163L2'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.403853, 50.09721], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'B',
#    'stop_id': 'U163Z2P',
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.405351, 50.098183], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'D',
#    'stop_id': 'U163Z5P',
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.405217, 50.098118], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.406089, 50.09734], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'F',
#    'stop_id': 'U163Z9P',
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.428855, 50.099571], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'A',
#    'stop_id': 'U231Z1P',
#    'stop_name': 'Kamenická',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.428417, 50.099705], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'B',
#    'stop_id': 'U231Z2P',
#    'stop_name': 'Kamenická',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.420581, 50.099705], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'B',
#    'stop_id': 'U262Z2P',
#    'stop_name': 'Korunovační',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.418202, 50.101105], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U262Z3P',
#    'stop_name': 'Korunovační',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.424091, 50.099949], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'A',
#    'stop_id': 'U324Z1P',
#    'stop_name': 'Letenské náměstí',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.423119, 50.100002], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'B',
#    'stop_id': 'U324Z2P',
#    'stop_name': 'Letenské náměstí',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.431299, 50.096321], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'A',
#    'stop_id': 'U439Z1P',
#    'stop_name': 'Nábřeží Kapitána Jaroše',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.431912, 50.104401], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'A',
#    'stop_id': 'U532Z1P',
#    'stop_name': 'Výstaviště',
#    'wheelchair_boarding': 2,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.432796, 50.104836], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'B',
#    'stop_id': 'U532Z2P',
#    'stop_name': 'Výstaviště',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.431238, 50.104118], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U532Z3P',
#    'stop_name': 'Výstaviště',
#    'wheelchair_boarding': 2,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.43072, 50.104191], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'D',
#    'stop_id': 'U532Z4P',
#    'stop_name': 'Výstaviště',
#    'wheelchair_boarding': 2,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.432889, 50.10421], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': '53',
#    'stop_id': 'U532Z53P',
#    'stop_name': 'Výstaviště',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.4186, 50.099258], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'A',
#    'stop_id': 'U692Z1P',
#    'stop_name': 'Sparta',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.416131, 50.098988], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'B',
#    'stop_id': 'U692Z2P',
#    'stop_name': 'Sparta',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.418045, 50.099072], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U692Z3P',
#    'stop_name': 'Sparta',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.417972, 50.099323], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'D',
#    'stop_id': 'U692Z4P',
#    'stop_name': 'Sparta',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.432893, 50.098896], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'A',
#    'stop_id': 'U717Z1P',
#    'stop_name': 'Strossmayerovo náměstí',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.433692, 50.098881], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'B',
#    'stop_id': 'U717Z2P',
#    'stop_name': 'Strossmayerovo náměstí',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.433256, 50.098644], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'D',
#    'stop_id': 'U717Z4P',
#    'stop_name': 'Strossmayerovo náměstí',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.433219, 50.09922], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U717Z5P',
#    'stop_name': 'Strossmayerovo náměstí',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.432813, 50.102245], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'A',
#    'stop_id': 'U841Z1P',
#    'stop_name': 'Veletržní palác',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [14.433183, 50.101482], 'type': 'Point'},
#   'properties': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'B',
#    'stop_id': 'U841Z2P',
#    'stop_name': 'Veletržní palác',
#    'wheelchair_boarding': 1,
#    'zone_id': 'P',
#    'level_id': None},
#   'type': 'Feature'}]

# %% [markdown]
# ### Stop times for each stop
# can be used as sanity check for actual scheduled times

# %%
url = 'https://api.golemio.cz/v2/gtfs/stoptimes/U163Z6P' # test for Hradčanská

params = {
    'date': '2024-12-02',
    'from': '07:12:33',
    'to': '12:12:33',
    'includeStop': 'true',
    'limit': 10,
    'offset': 0
}

headers = {
    'accept': 'application/json',
    'X-Access-Token': os.getenv('X-Access-Token-Golemio')
    }

response = requests.get(url, params=params, headers=headers)
response.json()
# Out:
# [{'arrival_time': '10:09:00',
#   'departure_time': '10:09:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1549_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}},
#  {'arrival_time': '10:19:00',
#   'departure_time': '10:19:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1508_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}},
#  {'arrival_time': '10:29:00',
#   'departure_time': '10:29:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1399_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}},
#  {'arrival_time': '10:39:00',
#   'departure_time': '10:39:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1446_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}},
#  {'arrival_time': '10:49:00',
#   'departure_time': '10:49:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1478_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}},
#  {'arrival_time': '10:59:00',
#   'departure_time': '10:59:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1551_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}},
#  {'arrival_time': '11:09:00',
#   'departure_time': '11:09:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1579_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}},
#  {'arrival_time': '11:19:00',
#   'departure_time': '11:19:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1401_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}},
#  {'arrival_time': '11:29:00',
#   'departure_time': '11:29:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1448_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}},
#  {'arrival_time': '11:39:00',
#   'departure_time': '11:39:00',
#   'drop_off_type': '3',
#   'pickup_type': '3',
#   'shape_dist_traveled': 0,
#   'stop_headsign': None,
#   'stop_id': 'U163Z6P',
#   'stop_sequence': 1,
#   'trip_id': '131_1510_241104',
#   'stop': {'location_type': 0,
#    'parent_station': None,
#    'platform_code': 'C',
#    'stop_id': 'U163Z6P',
#    'stop_lat': 50.098118,
#    'stop_lon': 14.405217,
#    'stop_name': 'Hradčanská',
#    'wheelchair_boarding': 0,
#    'zone_id': 'P',
#    'level_id': None}}]

# %% [markdown]
# ### Get actual delays
# parquet files examples provided by Golemio, if the project is agreed with, Golemio will provide desired parquet files for our use case
#
# important columns are `current_stop_dep_delay`, `current_stop_arr_delay` and `current_stop_departure`:
# - the scheduled departure is `current_stop_departure`
# - the actual departure is `current_stop_departure` + `current_stop_dep_delay` or `current_stop_arr_delay` if the dep delay is NULL
# - we can take either one of the delay values as the time spent at stop by normal public transport is 0
#
# this data will help us determine the real travel times and create base for the delay prediction

# %%
db = duckdb.connect()

# %%
df = db.sql("SELECT * FROM read_parquet('*.parquet')").df()

# %%
df[df['stop_name'] == 'Hradčanská'].head()
# Out:
#                                           rt_trip_id  gtfs_date  \
# 2867   2024-10-19T22:07:00+02:00_8_10717_240902_9095 2024-10-19
# 2969    2024-10-19T22:09:00+02:00_2_1342_240928_8268 2024-10-19
# 3019  2024-10-19T22:10:00+02:00_26_11296_240928_9281 2024-10-19
# 3323   2024-10-19T22:15:00+02:00_2_10645_240928_8263 2024-10-19
# 3518  2024-10-19T22:16:00+02:00_26_16705_240928_8532 2024-10-19
#
#          gtfs_trip_id  gtfs_direction_id gtfs_route_short_name  \
# 2867   8_10717_240902                  1                     8
# 2969    2_1342_240928                  0                     2
# 3019  26_11296_240928                  1                    26
# 3323   2_10645_240928                  1                     2
# 3518  26_16705_240928                  0                    26
#
#       gtfs_route_type  run_number  vehicle_registration_number  \
# 2867                0         1.0                       9095.0
# 2969                0        73.0                       8268.0
# 3019                0        10.0                       9281.0
# 3323                0        71.0                       8263.0
# 3518                0         5.0                       8532.0
#
#       gtfs_stop_sequence gtfs_stop_id  ... create_batch_id  \
# 2867                  25      U163Z2P  ...             NaN
# 2969                  10      U163Z1P  ...             NaN
# 3019                  33      U163Z2P  ...             NaN
# 3323                  18      U163Z2P  ...             NaN
# 3518                  17      U163Z1P  ...             NaN
#
#                            created_at  created_by  update_batch_id  \
# 2867 2024-10-20 00:18:00.179319+02:00        None              NaN
# 2969 2024-10-20 00:18:00.179319+02:00        None              NaN
# 3019 2024-10-20 00:18:00.179319+02:00        None              NaN
# 3323 2024-10-20 00:18:00.179319+02:00        None              NaN
# 3518 2024-10-20 00:18:00.179319+02:00        None              NaN
#
#                            updated_at updated_by origin_route_name  \
# 2867 2024-10-20 00:18:00.179319+02:00       None                 8
# 2969 2024-10-20 00:18:00.179319+02:00       None                93
# 3019 2024-10-20 00:18:00.179319+02:00       None                26
# 3323 2024-10-20 00:18:00.179319+02:00       None                91
# 3518 2024-10-20 00:18:00.179319+02:00       None                26
#
#        stop_name        lat        lng
# 2867  Hradčanská  50.097210  14.403853
# 2969  Hradčanská  50.097298  14.404873
# 3019  Hradčanská  50.097210  14.403853
# 3323  Hradčanská  50.097210  14.403853
# 3518  Hradčanská  50.097298  14.404873
#
# [5 rows x 24 columns]
